# %% [markdown]
# # Different ways to create pandas DataFrame

# %%
# !pip install pandas

# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\Admin\Desktop\Kaggle data new\List of companies in India.csv")

# %%
df
# Out:
#       Unnamed: 0                 Company_Name  Rating  \
# 0              0                          TCS     3.8
# 1              1                    Accenture     4.0
# 2              2                    Cognizant     3.9
# 3              3                        Wipro     3.8
# 4              4                    Capgemini     3.9
# ...          ...                          ...     ...
# 3212        3212    ISS SDB Security Services     4.4
# 3213        3213        Molecular Connections     3.4
# 3214        3214               Royal Research     2.1
# 3215        3215  CPM India Sales & Marketing     4.2
# 3216        3216        Cactus Communications     3.7
#
#                        Company_Type Company_Reviews          Headquarter  \
# 0         IT Services & Consulting            74.2k               Mumbai
# 1         IT Services & Consulting              47k               Dublin
# 2         IT Services & Consulting            42.4k  Teaneck. New Jersey
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # using xlsx

# %%
df2 = pd.read_excel(r"C:\Users\Admin\Desktop\Kaggle data new\HPI_master.xlsx")

# %%
df2
# Out:
#              hpi_type     hpi_flavor  frequency                   level  \
# 0         traditional  purchase-only    monthly  USA or Census Division
# 1         traditional  purchase-only    monthly  USA or Census Division
# 2         traditional  purchase-only    monthly  USA or Census Division
# 3         traditional  purchase-only    monthly  USA or Census Division
# 4         traditional  purchase-only    monthly  USA or Census Division
# ...               ...            ...        ...                     ...
# 124809  developmental  purchase-only  quarterly             Puerto Rico
# 124810  developmental  purchase-only  quarterly             Puerto Rico
# 124811  developmental  purchase-only  quarterly             Puerto Rico
# 124812  developmental  purchase-only  quarterly             Puerto Rico
# 124813  developmental  purchase-only  quarterly             Puerto Rico
#
#                          place_name place_id    yr  period  index_nsa  \
# ...

# %% [markdown]
# # create df from dictionary

# %%
py_dict = {
    "name":["Iron","copper","silver","alumina"],
    "seg":["a","h","g","r"],
    "price":[2323,34545,56768,98765]
}

# %%
py_dict
# Out:
# {'name': ['Iron', 'copper', 'silver', 'alumina'],
#  'seg': ['a', 'h', 'g', 'r'],
#  'price': [2323, 34545, 56768, 98765]}

# %%
df3 = pd.DataFrame(py_dict)

# %%
df3
# Out:
#       name seg  price
# 0     Iron   a   2323
# 1   copper   h  34545
# 2   silver   g  56768
# 3  alumina   r  98765

# %%
import pandas as pd
data = pd.DataFrame({ 'gender' : ['Male', 'Female', 'Male', 'Female', 'Female'],
                       'class' : ['A','B','C','D','A'],
                        'city' : ['Delhi','Gurugram','Delhi','Delhi','Gurugram'] })
data.head()
# Out:
#    gender class      city
# 0    Male     A     Delhi
# 1  Female     B  Gurugram
# 2    Male     C     Delhi
# 3  Female     D     Delhi
# 4  Female     A  Gurugram

# %% [markdown]
# # create df from list of dict

# %%
py = [
    {"id":101,"sales":2525,"temp":2345},
    {"id":102,"sales":5687,"temp":5645},
    {"id":103,"sales":3456,"temp":3785}
]

# %%
df5 = pd.DataFrame(py)

# %%
df5
# Out:
#     id  sales  temp
# 0  101   2525  2345
# 1  102   5687  5645
# 2  103   3456  3785

# %% [markdown]
# # creating data frame by using tuple list

# %%
emp_list = [
    (1/12/2023,"John","ML engg" ),
    (16/7/2022,"Rahul","DA"),
    (23/6/2022,"Vishal","DS")
]

# %%
df6 = pd.DataFrame(emp_list,columns = ["DOJ","Name","Designation"])

# %%
df6
# Out:
#         DOJ    Name Designation
# 0  0.000041    John     ML engg
# 1  0.001130   Rahul          DA
# 2  0.001896  Vishal          DS

# %% [markdown]
# # read data using web scrapping

# %%
df7 = pd.read_html("https://en.wikipedia.org/wiki/The_Godfather")

# %%
df7[1]      # here 1 is for first table
# Out:
#                                      Award  \
# 0                      45th Academy Awards
# 1                      45th Academy Awards
# 2                      45th Academy Awards
# 3                      45th Academy Awards
# 4                      45th Academy Awards
# 5                      45th Academy Awards
# 6                      45th Academy Awards
# 7                      45th Academy Awards
# 8                      45th Academy Awards
# 9                      45th Academy Awards
# 10                     45th Academy Awards
# 11        26th British Academy Film Awards
# 12        26th British Academy Film Awards
# 13        26th British Academy Film Awards
# 14        26th British Academy Film Awards
# 15        26th British Academy Film Awards
# 16  25th Directors Guild of America Awards
# 17                30th Golden Globe Awards
# 18                30th Golden Globe Awards
# 19                30th Golden Globe Awards
# 20                30th Golden Globe Awards
# ...

# %% [markdown]
# # read data from jason

# %%
df8 = pd.read_json(" ")
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_8980\3325649463.py:1: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df8 = pd.read_json(" ")
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 df8 = pd.read_json(" ")
#
# File ~\anaconda3\Lib\site-packages\pandas\io\json\_json.py:804, in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options, dtype_backend, engine)
#     802     return json_reader
#     803 else:
# --> 804     return json_reader.read()
#
# File ~\anaconda3\Lib\site-packages\pandas\io\json\_json.py:1014, in JsonReader.read(self)
# ...

# %% [markdown]
# # Operations on DataFrame

# %%
# 1. Fetch columns and rows from DataFrame

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\Admin\Desktop\Kaggle data new\List of companies in India.csv")

# %%
df
# Out:
#       Unnamed: 0                 Company_Name  Rating  \
# 0              0                          TCS     3.8
# 1              1                    Accenture     4.0
# 2              2                    Cognizant     3.9
# 3              3                        Wipro     3.8
# 4              4                    Capgemini     3.9
# ...          ...                          ...     ...
# 3212        3212    ISS SDB Security Services     4.4
# 3213        3213        Molecular Connections     3.4
# 3214        3214               Royal Research     2.1
# 3215        3215  CPM India Sales & Marketing     4.2
# 3216        3216        Cactus Communications     3.7
#
#                        Company_Type Company_Reviews          Headquarter  \
# 0         IT Services & Consulting            74.2k               Mumbai
# 1         IT Services & Consulting              47k               Dublin
# 2         IT Services & Consulting            42.4k  Teaneck. New Jersey
# ...

# %%
df.shape              #It will show roes and columns in DataFrame
# Out:
# (3217, 8)

# %%
# 2. Fetch specific columns from DataFrame

# %%
df["Company_Name"]     ## to fetch specific columns in DataFrame
# Out:
# 0                               TCS
# 1                         Accenture
# 2                         Cognizant
# 3                             Wipro
# 4                         Capgemini
#                    ...
# 3212      ISS SDB Security Services
# 3213          Molecular Connections
# 3214                 Royal Research
# 3215    CPM India Sales & Marketing
# 3216          Cactus Communications
# Name: Company_Name, Length: 3217, dtype: object

# %%
# 3. list of columns from DataFrame

# %%
df.columns             # to fetch all columns in DataFrame
# Out:
# Index(['Unnamed: 0', 'Company_Name', 'Rating', 'Company_Type',
#        'Company_Reviews', 'Headquarter', 'Company_Established_Year',
#        'No_of_Employes'],
#       dtype='object')

# %%
# 4 Fetch multiple columns from DataFrame

# %%
df[["Company_Name","Rating","Headquarter","No_of_Employes"]]
# Out:
#                      Company_Name  Rating          Headquarter No_of_Employes
# 0                             TCS     3.8               Mumbai        1 lakh+
# 1                       Accenture     4.0               Dublin        1 lakh+
# 2                       Cognizant     3.9  Teaneck. New Jersey        1 lakh+
# 3                           Wipro     3.8            Bangalore        1 lakh+
# 4                       Capgemini     3.9                Paris        1 lakh+
# ...                           ...     ...                  ...            ...
# 3212    ISS SDB Security Services     4.4               Mumbai        1k - 5k
# 3213        Molecular Connections     3.4            Bangalore        1k - 5k
# 3214               Royal Research     2.1              Kolkata       501 - 1k
# 3215  CPM India Sales & Marketing     4.2            New Delhi       501 - 1k
# 3216        Cactus Communications     3.7               Mumbai        1k - 5k
#
# [3217 rows x 4 columns]

# %%
# 5 add new column in DataFrame

# %%
import datetime

# %%
df['Last_updated_Date'] = datetime.datetime.now()

# %%
df
# Out:
#       Unnamed: 0                 Company_Name  Rating  \
# 0              0                          TCS     3.8
# 1              1                    Accenture     4.0
# 2              2                    Cognizant     3.9
# 3              3                        Wipro     3.8
# 4              4                    Capgemini     3.9
# ...          ...                          ...     ...
# 3212        3212    ISS SDB Security Services     4.4
# 3213        3213        Molecular Connections     3.4
# 3214        3214               Royal Research     2.1
# 3215        3215  CPM India Sales & Marketing     4.2
# 3216        3216        Cactus Communications     3.7
#
#                        Company_Type Company_Reviews          Headquarter  \
# 0         IT Services & Consulting            74.2k               Mumbai
# 1         IT Services & Consulting              47k               Dublin
# 2         IT Services & Consulting            42.4k  Teaneck. New Jersey
# ...

# %%
# 6 delete column from DataFrame

# %%
df.drop("Last_updted_Date",axis=1,inplace=True)

# %%
df
# Out:
#       Unnamed: 0                 Company_Name  Rating  \
# 0              0                          TCS     3.8
# 1              1                    Accenture     4.0
# 2              2                    Cognizant     3.9
# 3              3                        Wipro     3.8
# 4              4                    Capgemini     3.9
# ...          ...                          ...     ...
# 3212        3212    ISS SDB Security Services     4.4
# 3213        3213        Molecular Connections     3.4
# 3214        3214               Royal Research     2.1
# 3215        3215  CPM India Sales & Marketing     4.2
# 3216        3216        Cactus Communications     3.7
#
#                        Company_Type Company_Reviews          Headquarter  \
# 0         IT Services & Consulting            74.2k               Mumbai
# 1         IT Services & Consulting              47k               Dublin
# 2         IT Services & Consulting            42.4k  Teaneck. New Jersey
# ...

# %%
# in above there is axis used and inplace is used

# %%
# axis means for seaching in rows and columns
# axis have 2 arguments

# if axis=0    interpreter will search column name in rows of DataFrame 
# axis=1       interpreter will search column name in columns of DataFrame

# %%
# inplace   
 # inplace have 2 arguments
# inplace method is used to commit chages in DataFrame
# True  = will commit cahnges on DataFrame
# False =  changes will appear but won't commit

# %%
# 7 delete multiple columns from DataFrame

# %%
df
# Out:
#       Unnamed: 0                 Company_Name  Rating  \
# 0              0                          TCS     3.8
# 1              1                    Accenture     4.0
# 2              2                    Cognizant     3.9
# 3              3                        Wipro     3.8
# 4              4                    Capgemini     3.9
# ...          ...                          ...     ...
# 3212        3212    ISS SDB Security Services     4.4
# 3213        3213        Molecular Connections     3.4
# 3214        3214               Royal Research     2.1
# 3215        3215  CPM India Sales & Marketing     4.2
# 3216        3216        Cactus Communications     3.7
#
#                        Company_Type Company_Reviews          Headquarter  \
# 0         IT Services & Consulting            74.2k               Mumbai
# 1         IT Services & Consulting              47k               Dublin
# 2         IT Services & Consulting            42.4k  Teaneck. New Jersey
# ...

# %%
df.drop(columns=["Unnamed: 0","Company_Reviews",],axis=1,inplace=True)

# %%
df
# Out:
#                      Company_Name  Rating                   Company_Type  \
# 0                             TCS     3.8      IT Services & Consulting
# 1                       Accenture     4.0      IT Services & Consulting
# 2                       Cognizant     3.9      IT Services & Consulting
# 3                           Wipro     3.8      IT Services & Consulting
# 4                       Capgemini     3.9      IT Services & Consulting
# ...                           ...     ...                            ...
# 3212    ISS SDB Security Services     4.4  Facility Management Services
# 3213        Molecular Connections     3.4      IT Services & Consulting
# 3214               Royal Research     2.1               Analytics & KPO
# 3215  CPM India Sales & Marketing     4.2       Marketing & Advertising
# 3216        Cactus Communications     3.7              Software Product
#
#               Headquarter  Company_Established_Year No_of_Employes  \
# ...

# %%
#  8 create new DataFrame using selected columns of existing DataFrame

# %%
df10 = df[["Company_Name","Company_Type","Headquarter",]]

# %%
df10
# Out:
#                      Company_Name                   Company_Type  \
# 0                             TCS      IT Services & Consulting
# 1                       Accenture      IT Services & Consulting
# 2                       Cognizant      IT Services & Consulting
# 3                           Wipro      IT Services & Consulting
# 4                       Capgemini      IT Services & Consulting
# ...                           ...                            ...
# 3212    ISS SDB Security Services  Facility Management Services
# 3213        Molecular Connections      IT Services & Consulting
# 3214               Royal Research               Analytics & KPO
# 3215  CPM India Sales & Marketing       Marketing & Advertising
# 3216        Cactus Communications              Software Product
#
#               Headquarter
# 0                  Mumbai
# 1                  Dublin
# 2     Teaneck. New Jersey
# 3               Bangalore
# 4                   Paris
# ...                   ...
# ...

# %%
# 9 clean data using lambda function

# %%
df = pd.read_csv(r"C:\Users\Admin\Desktop\Kaggle data new\List of companies in India.csv")

# %%
df
# Out:
#       Unnamed: 0                 Company_Name  Rating  \
# 0              0                          TCS     3.8
# 1              1                    Accenture     4.0
# 2              2                    Cognizant     3.9
# 3              3                        Wipro     3.8
# 4              4                    Capgemini     3.9
# ...          ...                          ...     ...
# 3212        3212    ISS SDB Security Services     4.4
# 3213        3213        Molecular Connections     3.4
# 3214        3214               Royal Research     2.1
# 3215        3215  CPM India Sales & Marketing     4.2
# 3216        3216        Cactus Communications     3.7
#
#                        Company_Type Company_Reviews          Headquarter  \
# 0         IT Services & Consulting            74.2k               Mumbai
# 1         IT Services & Consulting              47k               Dublin
# 2         IT Services & Consulting            42.4k  Teaneck. New Jersey
# ...

# %%
df["Company_Type_New"] = df["Company_Type"].apply(lambda x:x.split('&')[0])

# %%
df
# Out:
#       Unnamed: 0                 Company_Name  Rating  \
# 0              0                          TCS     3.8
# 1              1                    Accenture     4.0
# 2              2                    Cognizant     3.9
# 3              3                        Wipro     3.8
# 4              4                    Capgemini     3.9
# ...          ...                          ...     ...
# 3212        3212    ISS SDB Security Services     4.4
# 3213        3213        Molecular Connections     3.4
# 3214        3214               Royal Research     2.1
# 3215        3215  CPM India Sales & Marketing     4.2
# 3216        3216        Cactus Communications     3.7
#
#                        Company_Type Company_Reviews          Headquarter  \
# 0         IT Services & Consulting            74.2k               Mumbai
# 1         IT Services & Consulting              47k               Dublin
# 2         IT Services & Consulting            42.4k  Teaneck. New Jersey
# ...

# %%
df = pd.read_csv(r"C:\Users\Admin\Desktop\Kaggle data new\List of companies in India.csv")

# %%
df
# Out:
#       Unnamed: 0                 Company_Name  Rating  \
# 0              0                          TCS     3.8
# 1              1                    Accenture     4.0
# 2              2                    Cognizant     3.9
# 3              3                        Wipro     3.8
# 4              4                    Capgemini     3.9
# ...          ...                          ...     ...
# 3212        3212    ISS SDB Security Services     4.4
# 3213        3213        Molecular Connections     3.4
# 3214        3214               Royal Research     2.1
# 3215        3215  CPM India Sales & Marketing     4.2
# 3216        3216        Cactus Communications     3.7
#
#                        Company_Type Company_Reviews          Headquarter  \
# 0         IT Services & Consulting            74.2k               Mumbai
# 1         IT Services & Consulting              47k               Dublin
# 2         IT Services & Consulting            42.4k  Teaneck. New Jersey
# ...

# %%
dict= [{"Emp_Id":1,"Emp_Name":"John Lee","Emp_Salary":85000,"E_Loc":"Pune",},
      {"Emp_Id":2,"Emp_Name":"Neha Sharma","Emp_Salary":75000,"E_Loc":"Banglore",},
      {"Emp_Id":3,"Emp_Name":"Vishal Mahire","Emp_Salary":90000,"E_Loc":"London",},
       {"Emp_Id":4,"Emp_Name":"Rahul Shirsath","Emp_Salary":45000,"E_Loc":"Mumbai",}
      ]

# %%
df3 = pd.DataFrame(dict)                 # here I've created dataframe from dict

# %%
df3
# Out:
#    Emp_Id        Emp_Name  Emp_Salary     E_Loc
# 0       1        John Lee       85000      Pune
# 1       2     Neha Sharma       75000  Banglore
# 2       3   Vishal Mahire       90000    London
# 3       4  Rahul Shirsath       45000    Mumbai

# %%
# 10 operations on specific columns
# if u want to give salary hike to all ur employees

# %%
df3["Updated_salary"]= df3["Emp_Salary"].apply(lambda x:x*1.3)

# %%
df3
# Out:
#    Emp_Id        Emp_Name  Emp_Salary     E_Loc  Updated_salary
# 0       1        John Lee       85000      Pune        110500.0
# 1       2     Neha Sharma       75000  Banglore         97500.0
# 2       3   Vishal Mahire       90000    London        117000.0
# 3       4  Rahul Shirsath       45000    Mumbai         58500.0

# %%
# 11 Encoding columns
# using various techniques
# a using lambda function
# b using map function
# c using normal function

# %%
df3
# Out:
#    Emp_Id        Emp_Name  Emp_Salary     E_Loc  Updated_salary
# 0       1        John Lee       85000      Pune        110500.0
# 1       2     Neha Sharma       75000  Banglore         97500.0
# 2       3   Vishal Mahire       90000    London        117000.0
# 3       4  Rahul Shirsath       45000    Mumbai         58500.0

# %%
dict5= [{"Emp_Id":1,"Emp_Name":"John Lee","Emp_Salary":85000,"Gender":"Male","E_Loc":"Pune",},
      {"Emp_Id":2,"Emp_Name":"Neha Sharma","Emp_Salary":75000,"Gender":"Female","E_Loc":"Banglore",},
      {"Emp_Id":3,"Emp_Name":"Vishal Mahire","Emp_Salary":90000,"Gender":"Male","E_Loc":"London",},
       {"Emp_Id":4,"Emp_Name":"Rahul Shirsath","Emp_Salary":45000,"Gender":"Male","E_Loc":"Mumbai",}
      ]

# %%
dict5
# Out:
# [{'Emp_Id': 1,
#   'Emp_Name': 'John Lee',
#   'Emp_Salary': 85000,
#   'Gender': 'Male',
#   'E_Loc': 'Pune'},
#  {'Emp_Id': 2,
#   'Emp_Name': 'Neha Sharma',
#   'Emp_Salary': 75000,
#   'Gender': 'Female',
#   'E_Loc': 'Banglore'},
#  {'Emp_Id': 3,
#   'Emp_Name': 'Vishal Mahire',
#   'Emp_Salary': 90000,
#   'Gender': 'Male',
#   'E_Loc': 'London'},
#  {'Emp_Id': 4,
#   'Emp_Name': 'Rahul Shirsath',
#   'Emp_Salary': 45000,
#   'Gender': 'Male',
#   'E_Loc': 'Mumbai'}]

# %%
df5 = pd.DataFrame(dict5)

# %%
df5
# Out:
#    Emp_Id        Emp_Name  Emp_Salary  Gender     E_Loc
# 0       1        John Lee       85000    Male      Pune
# 1       2     Neha Sharma       75000  Female  Banglore
# 2       3   Vishal Mahire       90000    Male    London
# 3       4  Rahul Shirsath       45000    Male    Mumbai

# %%
# a using lambda function

# %%
df5["Gender_Encode_Lambda"] = df5["Gender"].apply(lambda x:1 if x == "Male" else 0)

# %%
df5
# Out:
#    Emp_Id        Emp_Name  Emp_Salary  Gender     E_Loc  Gender_Encode_Lambda
# 0       1        John Lee       85000    Male      Pune                     1
# 1       2     Neha Sharma       75000  Female  Banglore                     0
# 2       3   Vishal Mahire       90000    Male    London                     1
# 3       4  Rahul Shirsath       45000    Male    Mumbai                     1

# %%
# b using map function

# %%
df5.drop("Gender_Encode_Lambda",axis=1,inplace=True)

# %%
df5
# Out:
#    Emp_Id        Emp_Name  Emp_Salary  Gender     E_Loc
# 0       1        John Lee       85000    Male      Pune
# 1       2     Neha Sharma       75000  Female  Banglore
# 2       3   Vishal Mahire       90000    Male    London
# 3       4  Rahul Shirsath       45000    Male    Mumbai

# %%
# b using map function

# %%
df5
# Out:
#    Emp_Id        Emp_Name  Emp_Salary  Gender     E_Loc
# 0       1        John Lee       85000    Male      Pune
# 1       2     Neha Sharma       75000  Female  Banglore
# 2       3   Vishal Mahire       90000    Male    London
# 3       4  Rahul Shirsath       45000    Male    Mumbai

# %%
df5["Encode_Gender_Map"]=df5["Gender"].map({"Male":1,"Female":0})

# %%
df5.drop("Encode_gender_Map",axis=1,inplace=True)

# %%
df5.drop("Encode_Gender_Map",axis=1,inplace=True)

# %%
df5
# Out:
#    Emp_Id        Emp_Name  Emp_Salary  Gender     E_Loc
# 0       1        John Lee       85000    Male      Pune
# 1       2     Neha Sharma       75000  Female  Banglore
# 2       3   Vishal Mahire       90000    Male    London
# 3       4  Rahul Shirsath       45000    Male    Mumbai

# %%
# C) using normal function
# noraml function is used when we want to use multiple conditions

# %%
df5
# Out:
#    Emp_Id        Emp_Name  Emp_Salary  Gender     E_Loc
# 0       1        John Lee       85000    Male      Pune
# 1       2     Neha Sharma       75000  Female  Banglore
# 2       3   Vishal Mahire       90000    Male    London
# 3       4  Rahul Shirsath       45000    Male    Mumbai

# %%
def encode(x):
    if x=="Male":
        return 1
    else:
        return 0

# %%
df5["Encode_Gender_normal_Function"]=df5["Gender"].apply(encode)

# %%
df5
# Out:
#    Emp_Id        Emp_Name  Emp_Salary  Gender     E_Loc  \
# 0       1        John Lee       85000    Male      Pune
# 1       2     Neha Sharma       75000  Female  Banglore
# 2       3   Vishal Mahire       90000    Male    London
# 3       4  Rahul Shirsath       45000    Male    Mumbai
#
#    Encode_Gender_normal_Function
# 0                              1
# 1                              0
# 2                              1
# 3                              1

# %%
# 12 split DOJ Date Month and Year

# %%
df5["E_DOJ"]=datetime.datetime.now()

# %%
df5
# Out:
#    Emp_Id        Emp_Name  Emp_Salary  Gender     E_Loc  \
# 0       1        John Lee       85000    Male      Pune
# 1       2     Neha Sharma       75000  Female  Banglore
# 2       3   Vishal Mahire       90000    Male    London
# 3       4  Rahul Shirsath       45000    Male    Mumbai
#
#    Encode_Gender_normal_Function                      E_DOJ
# 0                              1 2024-04-21 12:12:51.569217
# 1                              0 2024-04-21 12:12:51.569217
# 2                              1 2024-04-21 12:12:51.569217
# 3                              1 2024-04-21 12:12:51.569217

# %%
df5[Emp_DOJ] =
# Out:
#    Emp_Id        Emp_Name  Emp_Salary  Gender     E_Loc  \
# 0       1        John Lee       85000    Male      Pune
# 1       2     Neha Sharma       75000  Female  Banglore
# 2       3   Vishal Mahire       90000    Male    London
# 3       4  Rahul Shirsath       45000    Male    Mumbai
#
#    Encode_Gender_normal_Function                      E_DOJ
# 0                              1 2024-04-21 12:12:51.569217
# 1                              0 2024-04-21 12:12:51.569217
# 2                              1 2024-04-21 12:12:51.569217
# 3                              1 2024-04-21 12:12:51.569217

# %%
dict1 = [{"Emp_Id":1,"Emp_Name":"John Lee","Emp_Salary":85000,"E_DOJ":"12-12-2000","Gender":"Male","E_Loc":"Pune",},
      {"Emp_Id":2,"Emp_Name":"Neha Sharma","Emp_Salary":75000,"E_DOJ":"10-08-2003","Gender":"Female","E_Loc":"Banglore",},
      {"Emp_Id":3,"Emp_Name":"Vishal Mahire","Emp_Salary":90000,"E_DOJ":"08-05-2014","Gender":"Male","E_Loc":"London",},
       {"Emp_Id":4,"Emp_Name":"Rahul Shirsath","Emp_Salary":45000,"E_DOJ":"1-09-2007","Gender":"Male","E_Loc":"Mumbai",}
      ]

# %%
df6 = pd.DataFrame(dict1)

# %%
df6
# Out:
#    Emp_Id        Emp_Name  Emp_Salary       E_DOJ  Gender     E_Loc
# 0       1        John Lee       85000  12-12-2000    Male      Pune
# 1       2     Neha Sharma       75000  10-08-2003  Female  Banglore
# 2       3   Vishal Mahire       90000  08-05-2014    Male    London
# 3       4  Rahul Shirsath       45000   1-09-2007    Male    Mumbai

# %%
# 12 split DOJ Date Month and Year

# %%
df6["Date"]=df6["E_DOJ"].apply(lambda x:x.split("-")[0])

# %%
df6
# Out:
#    Emp_Id        Emp_Name  Emp_Salary       E_DOJ  Gender     E_Loc Date
# 0       1        John Lee       85000  12-12-2000    Male      Pune   12
# 1       2     Neha Sharma       75000  10-08-2003  Female  Banglore   10
# 2       3   Vishal Mahire       90000  08-05-2014    Male    London   08
# 3       4  Rahul Shirsath       45000   1-09-2007    Male    Mumbai    1

# %%
df6["Month"]=df6["E_DOJ"].apply(lambda x:x.split("-")[1])

# %%
df6["Year"]=df6["E_DOJ"].apply(lambda x:x.split("-")[2])

# %%
df6
# Out:
#    Emp_Id        Emp_Name  Emp_Salary       E_DOJ  Gender     E_Loc Date  \
# 0       1        John Lee       85000  12-12-2000    Male      Pune   12
# 1       2     Neha Sharma       75000  10-08-2003  Female  Banglore   10
# 2       3   Vishal Mahire       90000  08-05-2014    Male    London   08
# 3       4  Rahul Shirsath       45000   1-09-2007    Male    Mumbai    1
#
#   Month  Year
# 0    12  2000
# 1    08  2003
# 2    05  2014
# 3    09  2007

# %%
# Data definition operations

# we can perform Drop,Rename,Replace,Group by,Concatenation operations on clolumns

# %%
# 1 find null values from  columns

# %%
df6.isnull()
# Out:
#    Emp_Id  Emp_Name  Emp_Salary  E_DOJ  Gender  E_Loc   Date  Month   Year
# 0   False     False       False  False   False  False  False  False  False
# 1   False     False       False  False   False  False  False  False  False
# 2   False     False       False  False   False  False  False  False  False
# 3   False     False       False  False   False  False  False  False  False

# %%
df6.isnull().sum()
# Out:
# Emp_Id        0
# Emp_Name      0
# Emp_Salary    0
# E_DOJ         0
# Gender        0
# E_Loc         0
# Date          0
# Month         0
# Year          0
# dtype: int64

# %%
df6
# Out:
#    Emp_Id        Emp_Name  Emp_Salary       E_DOJ  Gender     E_Loc Date  \
# 0       1        John Lee       85000  12-12-2000    Male      Pune   12
# 1       2     Neha Sharma       75000  10-08-2003  Female  Banglore   10
# 2       3   Vishal Mahire       90000  08-05-2014    Male    London   08
# 3       4  Rahul Shirsath       45000   1-09-2007    Male    Mumbai    1
#
#   Month  Year
# 0    12  2000
# 1    08  2003
# 2    05  2014
# 3    09  2007

# %%
# 2 find unique values from speicific columns

# %%
df6
# Out:
#    Emp_Id        Emp_Name  Emp_Salary       E_DOJ  Gender     E_Loc Date  \
# 0       1        John Lee       85000  12-12-2000    Male      Pune   12
# 1       2     Neha Sharma       75000  10-08-2003  Female  Banglore   10
# 2       3   Vishal Mahire       90000  08-05-2014    Male    London   08
# 3       4  Rahul Shirsath       45000   1-09-2007    Male    Mumbai    1
#
#   Month  Year
# 0    12  2000
# 1    08  2003
# 2    05  2014
# 3    09  2007

# %%
# 2 find unique values from speicific columns

# %%
df6["E_Loc"].unique()
# Out:
# array(['Pune', 'Banglore', 'London', 'Mumbai'], dtype=object)

# %%
df6["E_DOJ"].unique()
# Out:
# array(['12-12-2000', '10-08-2003', '08-05-2014', '1-09-2007'],
#       dtype=object)

# %%
# 3 to find data type of each column

# %%
df6
# Out:
#    Emp_Id        Emp_Name  Emp_Salary       E_DOJ  Gender     E_Loc Date  \
# 0       1        John Lee       85000  12-12-2000    Male      Pune   12
# 1       2     Neha Sharma       75000  10-08-2003  Female  Banglore   10
# 2       3   Vishal Mahire       90000  08-05-2014    Male    London   08
# 3       4  Rahul Shirsath       45000   1-09-2007    Male    Mumbai    1
#
#   Month  Year
# 0    12  2000
# 1    08  2003
# 2    05  2014
# 3    09  2007

# %%
df6.dtypes
# Out:
# Emp_Id         int64
# Emp_Name      object
# Emp_Salary     int64
# E_DOJ         object
# Gender        object
# E_Loc         object
# Date          object
# Month         object
# Year          object
# dtype: object

# %%
#  REMEMBER
# in pandas string is denoted as object

# %%
# 4  change data type of existing column

# %%
import pandas as pd

# %%
df6
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df6
#
# NameError: name 'df6' is not defined

# %%
df6["Emp_Id"]= df6["Emp_Id"].astype("object")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df6["Emp_Id"]= df6["Emp_Id"].astype("object")
#
# NameError: name 'df6' is not defined

# %%
dict1 = [{"Emp_Id":1,"Emp_Name":"John Lee","Emp_Salary":85000,"E_DOJ":"12-12-2000","Gender":"Male","E_Loc":"Pune",},
      {"Emp_Id":2,"Emp_Name":"Neha Sharma","Emp_Salary":75000,"E_DOJ":"10-08-2003","Gender":"Female","E_Loc":"Banglore",},
      {"Emp_Id":3,"Emp_Name":"Vishal Mahire","Emp_Salary":90000,"E_DOJ":"08-05-2014","Gender":"Male","E_Loc":"London",},
       {"Emp_Id":4,"Emp_Name":"Rahul Shirsath","Emp_Salary":45000,"E_DOJ":"1-09-2007","Gender":"Male","E_Loc":"Mumbai",}
      ]

# %%
df7 = pd.DataFrame(dict1)

# %%
df7
# Out:
#    Emp_Id        Emp_Name  Emp_Salary       E_DOJ  Gender     E_Loc
# 0       1        John Lee       85000  12-12-2000    Male      Pune
# 1       2     Neha Sharma       75000  10-08-2003  Female  Banglore
# 2       3   Vishal Mahire       90000  08-05-2014    Male    London
# 3       4  Rahul Shirsath       45000   1-09-2007    Male    Mumbai

# %%
df7["Emp_Id"]= df7["Emp_Id"].astype("object")

# %%
df7.dtypes
# Out:
# Emp_Id        object
# Emp_Name      object
# Emp_Salary     int64
# E_DOJ         object
# Gender        object
# E_Loc         object
# dtype: object

# %%
df7.dtypes
# Out:
# Emp_Id        object
# Emp_Name      object
# Emp_Salary     int64
# E_DOJ         object
# Gender        object
# E_Loc         object
# dtype: object

# %%
# 5 delete rows which have null values

# %%
df = df7

# %%
df
# Out:
#   Emp_Id        Emp_Name  Emp_Salary       E_DOJ  Gender     E_Loc
# 0      1        John Lee       85000  12-12-2000    Male      Pune
# 1      2     Neha Sharma       75000  10-08-2003  Female  Banglore
# 2      3   Vishal Mahire       90000  08-05-2014    Male    London
# 3      4  Rahul Shirsath       45000   1-09-2007    Male    Mumbai

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (4, 6)

# %%
dict2 = [{"Emp_Id":1,"Emp_Name":"John Lee","Emp_Salary":85000,"E_DOJ":"12-12-2000","Gender":"Male","E_Loc":"Pune",},
      {"Emp_Id":2,"Emp_Name":"Neha Sharma","Emp_Salary":"NaN","E_DOJ":"10-08-2003","Gender":"Female","E_Loc":"Banglore",},
      {"Emp_Id":3,"Emp_Name":"Vishal Mahire","Emp_Salary":90000,"E_DOJ":"08-05-2014","Gender":"Male","E_Loc":"London",},
       {"Emp_Id":4,"Emp_Name":"Rahul Shirsath","Emp_Salary":45000,"E_DOJ":"1-09-2007","Gender":"Male","E_Loc":"NewYork",},
    {"Emp_Id":5,"Emp_Name":"naina","Emp_Salary":45000,"E_DOJ":"1-09-2007","Gender":"Female","E_Loc":"Mumbai",},
    {"Emp_Id":6,"Emp_Name":"Farhan","Emp_Salary":"NaN","E_DOJ":"1-09-2007","Gender":"Male","E_Loc":"Madrid",},
    {"Emp_Id":7,"Emp_Name":"Laila","Emp_Salary":45000,"E_DOJ":"1-09-2007","Gender":"Female","E_Loc":"Dublin",}
      ]

# %%
df = pd.DataFrame(dict2)

# %%
df
# Out:
#    Emp_Id        Emp_Name Emp_Salary       E_DOJ  Gender     E_Loc
# 0       1        John Lee      85000  12-12-2000    Male      Pune
# 1       2     Neha Sharma       null  10-08-2003  Female  Banglore
# 2       3   Vishal Mahire      90000  08-05-2014    Male    London
# 3       4  Rahul Shirsath      45000   1-09-2007    Male   NewYork
# 4       5           naina      45000   1-09-2007  Female    Mumbai
# 5       6          Farhan       null   1-09-2007    Male    Madrid
# 6       7           Laila      45000   1-09-2007  Female    Dublin

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (7, 6)

# %%
df
# Out:
#    Emp_Id        Emp_Name Emp_Salary       E_DOJ  Gender     E_Loc
# 0       1        John Lee      85000  12-12-2000    Male      Pune
# 1       2     Neha Sharma       null  10-08-2003  Female  Banglore
# 2       3   Vishal Mahire      90000  08-05-2014    Male    London
# 3       4  Rahul Shirsath      45000   1-09-2007    Male   NewYork
# 4       4           naina      45000   1-09-2007  Female    Mumbai
# 5       4          Farhan       null   1-09-2007    Male    Madrid
# 6       4           Laila      45000   1-09-2007  Female    Dublin

# %%
df
# Out:
#    Emp_Id        Emp_Name Emp_Salary       E_DOJ  Gender     E_Loc
# 0       1        John Lee      85000  12-12-2000    Male      Pune
# 1       2     Neha Sharma        NaN  10-08-2003  Female  Banglore
# 2       3   Vishal Mahire      90000  08-05-2014    Male    London
# 3       4  Rahul Shirsath      45000   1-09-2007    Male   NewYork
# 4       5           naina      45000   1-09-2007  Female    Mumbai
# 5       6          Farhan        NaN   1-09-2007    Male    Madrid
# 6       7           Laila      45000   1-09-2007  Female    Dublin

# %%
df.dropna(axis=1,how="any",subset=["Emp_Salary"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10800\2749743114.py in ?()
# ----> 1 df.dropna(axis=1,how="any",subset=["Emp_Salary"])
#
# ~\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, axis, how, thresh, subset, inplace, ignore_index)
#    6414             ax = self._get_axis(agg_axis)
#    6415             indices = ax.get_indexer_for(subset)
#    6416             check = indices == -1
#    6417             if check.any():
# -> 6418                 raise KeyError(np.array(subset)[check].tolist())
#    6419             agg_obj = self.take(indices, axis=agg_axis)
#    6420
#    6421         if thresh is not lib.no_default:
#
# KeyError: ['Emp_Salary']

# %%
df
# Out:
#    Emp_Id        Emp_Name Emp_Salary       E_DOJ  Gender     E_Loc
# 0       1        John Lee      85000  12-12-2000    Male      Pune
# 1       2     Neha Sharma        NaN  10-08-2003  Female  Banglore
# 2       3   Vishal Mahire      90000  08-05-2014    Male    London
# 3       4  Rahul Shirsath      45000   1-09-2007    Male   NewYork
# 4       5           naina      45000   1-09-2007  Female    Mumbai
# 5       6          Farhan        NaN   1-09-2007    Male    Madrid
# 6       7           Laila      45000   1-09-2007  Female    Dublin

# %%
# 7 Replace none values from DataFrame

import numpy as np

# %%
df.replace(np.nan,"NA")
# Out:
#    Emp_Id        Emp_Name Emp_Salary       E_DOJ  Gender     E_Loc
# 0       1        John Lee      85000  12-12-2000    Male      Pune
# 1       2     Neha Sharma        NaN  10-08-2003  Female  Banglore
# 2       3   Vishal Mahire      90000  08-05-2014    Male    London
# 3       4  Rahul Shirsath      45000   1-09-2007    Male   NewYork
# 4       5           naina      45000   1-09-2007  Female    Mumbai
# 5       6          Farhan        NaN   1-09-2007    Male    Madrid
# 6       7           Laila      45000   1-09-2007  Female    Dublin

# %%
# 8 Repalce encoding of columns

# %%
df
# Out:
#    Emp_Id        Emp_Name Emp_Salary       E_DOJ  Gender     E_Loc
# 0       1        John Lee      85000  12-12-2000    Male      Pune
# 1       2     Neha Sharma        NaN  10-08-2003  Female  Banglore
# 2       3   Vishal Mahire      90000  08-05-2014    Male    London
# 3       4  Rahul Shirsath      45000   1-09-2007    Male   NewYork
# 4       5           naina      45000   1-09-2007  Female    Mumbai
# 5       6          Farhan        NaN   1-09-2007    Male    Madrid
# 6       7           Laila      45000   1-09-2007  Female    Dublin

# %%
df.replace(["Male","Female"],[1,0])
# Out:
#    Emp_Id        Emp_Name Emp_Salary       E_DOJ  Gender     E_Loc
# 0       1        John Lee      85000  12-12-2000       1      Pune
# 1       2     Neha Sharma        NaN  10-08-2003       0  Banglore
# 2       3   Vishal Mahire      90000  08-05-2014       1    London
# 3       4  Rahul Shirsath      45000   1-09-2007       1   NewYork
# 4       5           naina      45000   1-09-2007       0    Mumbai
# 5       6          Farhan        NaN   1-09-2007       1    Madrid
# 6       7           Laila      45000   1-09-2007       0    Dublin

# %%
# 9 USE group by clause

# %%
df.groupby("E_Loc")

# %%
obj = df.groupby("E_Loc")

# %%
obj.get_group("Mumbai")
# Out:
#    Emp_Id Emp_Name Emp_Salary      E_DOJ  Gender   E_Loc
# 4       5    naina      45000  1-09-2007  Female  Mumbai

# %%
obj.size()
# Out:
# E_Loc
# Banglore    1
# Dublin      1
# London      1
# Madrid      1
# Mumbai      1
# NewYork     1
# Pune        1
# dtype: int64

# %%
# 10 Rename existing columns

df.rename({"E_Loc":"Emp_Location","E_DOJ":"Emp_DOJ"},axis=1,inplace=True)

# %%
df
# Out:
#    Emp_Id        Emp_Name Emp_Salary     Emp_DOJ  Gender Emp_Location
# 0       1        John Lee      85000  12-12-2000    Male         Pune
# 1       2     Neha Sharma        NaN  10-08-2003  Female     Banglore
# 2       3   Vishal Mahire      90000  08-05-2014    Male       London
# 3       4  Rahul Shirsath      45000   1-09-2007    Male      NewYork
# 4       5           naina      45000   1-09-2007  Female       Mumbai
# 5       6          Farhan        NaN   1-09-2007    Male       Madrid
# 6       7           Laila      45000   1-09-2007  Female       Dublin

# %%
df.columns=["E_Name","E_Salary","E_Location","Emp_Id","Emp_DOJ","Gender"]

# %%
df
# Out:
#    E_Name        E_Salary E_Location      Emp_Id Emp_DOJ    Gender
# 0       1        John Lee      85000  12-12-2000    Male      Pune
# 1       2     Neha Sharma        NaN  10-08-2003  Female  Banglore
# 2       3   Vishal Mahire      90000  08-05-2014    Male    London
# 3       4  Rahul Shirsath      45000   1-09-2007    Male   NewYork
# 4       5           naina      45000   1-09-2007  Female    Mumbai
# 5       6          Farhan        NaN   1-09-2007    Male    Madrid
# 6       7           Laila      45000   1-09-2007  Female    Dublin

# %%
df.columns=["Emp_Id","E_Name","E_Salary","Emp_DOJ","Gender","E_Location",]

# %%
df
# Out:
#    Emp_Id          E_Name E_Salary     Emp_DOJ  Gender E_Location
# 0       1        John Lee    85000  12-12-2000    Male       Pune
# 1       2     Neha Sharma      NaN  10-08-2003  Female   Banglore
# 2       3   Vishal Mahire    90000  08-05-2014    Male     London
# 3       4  Rahul Shirsath    45000   1-09-2007    Male    NewYork
# 4       5           naina    45000   1-09-2007  Female     Mumbai
# 5       6          Farhan      NaN   1-09-2007    Male     Madrid
# 6       7           Laila    45000   1-09-2007  Female     Dublin

# %%
import pandas as pd

# %%
# 11 concatenation of DataFrame

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
dict1 = [{"Emp_Id":1,"Emp_Name":"John Lee","Emp_Salary":85000,"E_DOJ":"12-12-2000","Gender":"Male","E_Loc":"Pune",},
      {"Emp_Id":2,"Emp_Name":"Neha Sharma","Emp_Salary":"NaN","E_DOJ":"10-08-2003","Gender":"Female","E_Loc":"Banglore",},
      
       {"Emp_Id":4,"Emp_Name":"Rahul Shirsath","Emp_Salary":45000,"E_DOJ":"1-09-2007","Gender":"Male","E_Loc":"NewYork",},
    {"Emp_Id":5,"Emp_Name":"naina","Emp_Salary":45000,"E_DOJ":"1-09-2007","Gender":"Female","E_Loc":"Mumbai",},
    {"Emp_Id":6,"Emp_Name":"Farhan","Emp_Salary":"NaN","E_DOJ":"1-09-2007","Gender":"Male","E_Loc":"Madrid",},
    {"Emp_Id":7,"Emp_Name":"Laila","Emp_Salary":45000,"E_DOJ":"1-09-2007","Gender":"Female","E_Loc":"Dublin",}
      ]

# %%
df1 = pd.DataFrame(dict1)

# %%
df1
# Out:
#    Emp_Id        Emp_Name Emp_Salary       E_DOJ  Gender     E_Loc
# 0       1        John Lee      85000  12-12-2000    Male      Pune
# 1       2     Neha Sharma        NaN  10-08-2003  Female  Banglore
# 2       4  Rahul Shirsath      45000   1-09-2007    Male   NewYork
# 3       5           naina      45000   1-09-2007  Female    Mumbai
# 4       6          Farhan        NaN   1-09-2007    Male    Madrid
# 5       7           Laila      45000   1-09-2007  Female    Dublin

# %%
dict2 = [{"Emp_Id":1,"Emp_Name":"John Lee","Emp_Salary":85000,"E_DOJ":"12-12-2000","Gender":"Male","E_Loc":"Pune",},
      {"Emp_Id":2,"Emp_Name":"Neha Sharma","Emp_Salary":"NaN","E_DOJ":"10-08-2003","Gender":"Female","E_Loc":"Banglore",},
      
       
    {"Emp_Id":5,"Emp_Name":"naina","Emp_Salary":45000,"E_DOJ":"1-09-2007","Gender":"Female","E_Loc":"Mumbai",},
    {"Emp_Id":6,"Emp_Name":"Farhan","Emp_Salary":"NaN","E_DOJ":"1-09-2007","Gender":"Male","E_Loc":"Madrid",},
    {"Emp_Id":7,"Emp_Name":"Laila","Emp_Salary":45000,"E_DOJ":"1-09-2007","Gender":"Female","E_Loc":"Dublin",}
      ]

# %%
df2 = pd.DataFrame(dict2)

# %%
df3 = pd.read_csv(r"C:\Users\Admin\OneDrive\Desktop\Kaggle data new\Anime_ratings.csv")

# %%
df3
# Out:
#                                                    Title  \
# 0             Kaguya-sama wa Kokurasetai: Ultra Romantic
# 1                             3-gatsu no Lion 2nd Season
# 2      Gintama Movie 2: Kanketsu-hen - Yorozuya yo Ei...
# 3                                               Gintama.
# 4                                         Koe no Katachi
# ...                                                  ...
# 20338                                        Steins;Gate
# 20339                                         High Score
# 20340                                           Noraneko
# 20341             Suki de Suki de, Suki de The Animation
# 20342                            Koihime†Musou OVA Omake
#
#                                Genres   Rank  Popularity  Score Episodes  \
# 0                     Comedy,Suspense     13         404   8.99       12
# 1                 Drama,Slice of Life     14         533   8.96       22
# ...

# %%
df7 = pd.concat([df2,df3,df1])

# %%
df7.head(20)
# Out:
#     Emp_Id     Emp_Name Emp_Salary       E_DOJ  Gender     E_Loc  \
# 0      1.0     John Lee      85000  12-12-2000    Male      Pune
# 1      2.0  Neha Sharma        NaN  10-08-2003  Female  Banglore
# 2      5.0        naina      45000   1-09-2007  Female    Mumbai
# 3      6.0       Farhan        NaN   1-09-2007    Male    Madrid
# 4      7.0        Laila      45000   1-09-2007  Female    Dublin
# 0      NaN          NaN        NaN         NaN     NaN       NaN
# 1      NaN          NaN        NaN         NaN     NaN       NaN
# 2      NaN          NaN        NaN         NaN     NaN       NaN
# 3      NaN          NaN        NaN         NaN     NaN       NaN
# 4      NaN          NaN        NaN         NaN     NaN       NaN
# 5      NaN          NaN        NaN         NaN     NaN       NaN
# 6      NaN          NaN        NaN         NaN     NaN       NaN
# 7      NaN          NaN        NaN         NaN     NaN       NaN
# ...

# %%
df7.tail(20)
# Out:
#        Emp_Id        Emp_Name Emp_Salary       E_DOJ  Gender     E_Loc  \
# 20329     NaN             NaN        NaN         NaN     NaN       NaN
# 20330     NaN             NaN        NaN         NaN     NaN       NaN
# 20331     NaN             NaN        NaN         NaN     NaN       NaN
# 20332     NaN             NaN        NaN         NaN     NaN       NaN
# 20333     NaN             NaN        NaN         NaN     NaN       NaN
# 20334     NaN             NaN        NaN         NaN     NaN       NaN
# 20335     NaN             NaN        NaN         NaN     NaN       NaN
# 20336     NaN             NaN        NaN         NaN     NaN       NaN
# 20337     NaN             NaN        NaN         NaN     NaN       NaN
# 20338     NaN             NaN        NaN         NaN     NaN       NaN
# 20339     NaN             NaN        NaN         NaN     NaN       NaN
# 20340     NaN             NaN        NaN         NaN     NaN       NaN
# ...

# %%
new_col = pd.Series([10,20,230])

# %%
df7 =pd.concat([df7,new_col],axis=1)

# %%
df7
# Out:
#     Emp_Id        Emp_Name Emp_Salary       E_DOJ  Gender     E_Loc Title  \
# 0      1.0        John Lee      85000  12-12-2000    Male      Pune   NaN
# 1      2.0     Neha Sharma        NaN  10-08-2003  Female  Banglore   NaN
# 2      5.0           naina      45000   1-09-2007  Female    Mumbai   NaN
# 3      6.0          Farhan        NaN   1-09-2007    Male    Madrid   NaN
# 4      7.0           Laila      45000   1-09-2007  Female    Dublin   NaN
# ..     ...             ...        ...         ...     ...       ...   ...
# 1      2.0     Neha Sharma        NaN  10-08-2003  Female  Banglore   NaN
# 2      4.0  Rahul Shirsath      45000   1-09-2007    Male   NewYork   NaN
# 3      5.0           naina      45000   1-09-2007  Female    Mumbai   NaN
# 4      6.0          Farhan        NaN   1-09-2007    Male    Madrid   NaN
# 5      7.0           Laila      45000   1-09-2007  Female    Dublin   NaN
#
#    Genres Rank  Popularity  Score Episodes Episode length Release Date      0
# ...

# %%
# Aggregate function

# %%
# 1 max func

# %%
df=pd.read_csv(r"C:\Users\Admin\OneDrive\Desktop\Kaggle data new\diabetes_risk_prediction_dataset.csv")

# %%
df
# Out:
#      Age  Gender Polyuria Polydipsia sudden weight loss weakness Polyphagia  \
# 0     40    Male       No        Yes                 No      Yes         No
# 1     58    Male       No         No                 No      Yes         No
# 2     41    Male      Yes         No                 No      Yes        Yes
# 3     45    Male       No         No                Yes      Yes        Yes
# 4     60    Male      Yes        Yes                Yes      Yes        Yes
# ..   ...     ...      ...        ...                ...      ...        ...
# 515   39  Female      Yes        Yes                Yes       No        Yes
# 516   48  Female      Yes        Yes                Yes      Yes        Yes
# 517   58  Female      Yes        Yes                Yes      Yes        Yes
# 518   32  Female       No         No                 No      Yes         No
# 519   42    Male       No         No                 No       No         No
#
# ...

# %%
df["Age"]==df["Age"].max()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 515    False
# 516    False
# 517    False
# 518    False
# 519    False
# Name: Age, Length: 520, dtype: bool

# %%
df[df["Age"]==df["Age"].max()]
# Out:
#      Age  Gender Polyuria Polydipsia sudden weight loss weakness Polyphagia  \
# 102   90  Female       No        Yes                Yes       No         No
# 186   90  Female       No        Yes                Yes       No         No
#
#     Genital thrush visual blurring Itching Irritability delayed healing  \
# 102            Yes             Yes     Yes           No              No
# 186            Yes             Yes     Yes           No              No
#
#     partial paresis muscle stiffness Alopecia Obesity     class
# 102              No              Yes      Yes      No  Positive
# 186              No              Yes      Yes      No  Positive

# %%
# 2 min func

# %%
df
# Out:
#      Age  Gender Polyuria Polydipsia sudden weight loss weakness Polyphagia  \
# 0     40    Male       No        Yes                 No      Yes         No
# 1     58    Male       No         No                 No      Yes         No
# 2     41    Male      Yes         No                 No      Yes        Yes
# 3     45    Male       No         No                Yes      Yes        Yes
# 4     60    Male      Yes        Yes                Yes      Yes        Yes
# ..   ...     ...      ...        ...                ...      ...        ...
# 515   39  Female      Yes        Yes                Yes       No        Yes
# 516   48  Female      Yes        Yes                Yes      Yes        Yes
# 517   58  Female      Yes        Yes                Yes      Yes        Yes
# 518   32  Female       No         No                 No      Yes         No
# 519   42    Male       No         No                 No       No         No
#
# ...

# %%
df[df["Age"]==df["Age"].min()]
# Out:
#      Age Gender Polyuria Polydipsia sudden weight loss weakness Polyphagia  \
# 133   16   Male      Yes         No                Yes       No        Yes
#
#     Genital thrush visual blurring Itching Irritability delayed healing  \
# 133             No              No      No           No              No
#
#     partial paresis muscle stiffness Alopecia Obesity     class
# 133              No               No       No      No  Positive

# %%
# 3 mean func

# %%
df["Age"].mean()
# Out:
# 48.02884615384615

# %%
# 4 std deviation func

# %%
df["Age"].std()
# Out:
# 12.151465995249461

# %%
# comparison operator

# %%
df[df["Age"]==40]  #who has age 40
# Out:
#      Age  Gender Polyuria Polydipsia sudden weight loss weakness Polyphagia  \
# 0     40    Male       No        Yes                 No      Yes         No
# 44    40  Female      Yes        Yes                Yes      Yes         No
# 65    40  Female      Yes         No                Yes       No        Yes
# 70    40  Female       No         No                Yes      Yes         No
# 92    40  Female      Yes        Yes                Yes      Yes         No
# 93    40  Female      Yes        Yes                 No      Yes        Yes
# 122   40    Male       No        Yes                 No      Yes        Yes
# 139   40    Male      Yes         No                 No       No         No
# 165   40  Female      Yes        Yes                Yes      Yes         No
# 180   40  Female      Yes        Yes                Yes      Yes         No
# 200   40    Male       No        Yes                Yes      Yes         No
# ...

# %%
df[df["Age"]>40]   #greater than 40
# Out:
#      Age  Gender Polyuria Polydipsia sudden weight loss weakness Polyphagia  \
# 1     58    Male       No         No                 No      Yes         No
# 2     41    Male      Yes         No                 No      Yes        Yes
# 3     45    Male       No         No                Yes      Yes        Yes
# 4     60    Male      Yes        Yes                Yes      Yes        Yes
# 5     55    Male      Yes        Yes                 No      Yes        Yes
# ..   ...     ...      ...        ...                ...      ...        ...
# 513   62  Female      Yes        Yes                Yes      Yes         No
# 514   54  Female      Yes        Yes                Yes      Yes        Yes
# 516   48  Female      Yes        Yes                Yes      Yes        Yes
# 517   58  Female      Yes        Yes                Yes      Yes        Yes
# 519   42    Male       No         No                 No       No         No
#
# ...

# %%
df[df["Age"]<40]   # less than 40
# Out:
#      Age  Gender Polyuria Polydipsia sudden weight loss weakness Polyphagia  \
# 11    38    Male      Yes        Yes                 No       No        Yes
# 12    35    Male      Yes         No                 No       No        Yes
# 22    39    Male      Yes         No                Yes       No         No
# 25    32    Male       No         No                 No       No         No
# 28    38    Male       No        Yes                 No       No         No
# ..   ...     ...      ...        ...                ...      ...        ...
# 494   36    Male       No         No                 No       No         No
# 504   38    Male       No         No                 No       No         No
# 505   35    Male       No         No                 No       No         No
# 515   39  Female      Yes        Yes                Yes       No        Yes
# 518   32  Female       No         No                 No      Yes         No
#
# ...

# %%
df[(df["Age"]>30) & (df["Age"]<41)]
# Out:
#      Age  Gender Polyuria Polydipsia sudden weight loss weakness Polyphagia  \
# 0     40    Male       No        Yes                 No      Yes         No
# 11    38    Male      Yes        Yes                 No       No        Yes
# 12    35    Male      Yes         No                 No       No        Yes
# 22    39    Male      Yes         No                Yes       No         No
# 25    32    Male       No         No                 No       No         No
# ..   ...     ...      ...        ...                ...      ...        ...
# 494   36    Male       No         No                 No       No         No
# 504   38    Male       No         No                 No       No         No
# 505   35    Male       No         No                 No       No         No
# 515   39  Female      Yes        Yes                Yes       No        Yes
# 518   32  Female       No         No                 No      Yes         No
#
# ...

# %%
# indexing     to set specific column at  1st position or index

# %%
df.set_index("Age",inplace = True)

# %%
df
# Out:
#      Gender Polyuria Polydipsia sudden weight loss weakness Polyphagia  \
# Age
# 40     Male       No        Yes                 No      Yes         No
# 58     Male       No         No                 No      Yes         No
# 41     Male      Yes         No                 No      Yes        Yes
# 45     Male       No         No                Yes      Yes        Yes
# 60     Male      Yes        Yes                Yes      Yes        Yes
# ..      ...      ...        ...                ...      ...        ...
# 39   Female      Yes        Yes                Yes       No        Yes
# 48   Female      Yes        Yes                Yes      Yes        Yes
# 58   Female      Yes        Yes                Yes      Yes        Yes
# 32   Female       No         No                 No      Yes         No
# 42     Male       No         No                 No       No         No
#
#     Genital thrush visual blurring Itching Irritability delayed healing  \
# Age
# ...

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#      Age  Gender Polyuria Polydipsia sudden weight loss weakness Polyphagia  \
# 0     40    Male       No        Yes                 No      Yes         No
# 1     58    Male       No         No                 No      Yes         No
# 2     41    Male      Yes         No                 No      Yes        Yes
# 3     45    Male       No         No                Yes      Yes        Yes
# 4     60    Male      Yes        Yes                Yes      Yes        Yes
# ..   ...     ...      ...        ...                ...      ...        ...
# 515   39  Female      Yes        Yes                Yes       No        Yes
# 516   48  Female      Yes        Yes                Yes      Yes        Yes
# 517   58  Female      Yes        Yes                Yes      Yes        Yes
# 518   32  Female       No         No                 No      Yes         No
# 519   42    Male       No         No                 No       No         No
#
# ...

# %%
# Loc iLoc function     VIMP

# %%
# the loc and iloc function in pandas are used to slice the dataset and filter out row wise data

# %%
df
# Out:
#      Age  Gender Polyuria Polydipsia sudden weight loss weakness Polyphagia  \
# 0     40    Male       No        Yes                 No      Yes         No
# 1     58    Male       No         No                 No      Yes         No
# 2     41    Male      Yes         No                 No      Yes        Yes
# 3     45    Male       No         No                Yes      Yes        Yes
# 4     60    Male      Yes        Yes                Yes      Yes        Yes
# ..   ...     ...      ...        ...                ...      ...        ...
# 515   39  Female      Yes        Yes                Yes       No        Yes
# 516   48  Female      Yes        Yes                Yes      Yes        Yes
# 517   58  Female      Yes        Yes                Yes      Yes        Yes
# 518   32  Female       No         No                 No      Yes         No
# 519   42    Male       No         No                 No       No         No
#
# ...

# %%
df.loc['Gender']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 df.loc['Gender']
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1153, in _LocationIndexer.__getitem__(self, key)
#    1150 axis = self.axis or 0
#    1152 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1153 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1393, in _LocIndexer._getitem_axis(self, key, axis)
#    1391 # fall thru to straight lookup
#    1392 self._validate_key(key, axis)
# -> 1393 return self._get_label(key, axis=axis)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1343, in _LocIndexer._get_label(self, label, axis)
#    1341 def _get_label(self, label, axis: AxisInt):
#    1342     # GH#5567 this will fail if the label is not present in the axis.
# ...

# %%
df1 = pd.read_csv(r"C:\Users\Admin\OneDrive\Desktop\Kaggle data new\Youth_Tobacco_Survey__YTS__Data.csv")

# %%
df1
# Out:
#        YEAR LocationAbbr   LocationDesc                  TopicType  \
# 0      2004           OH           Ohio  Tobacco Use – Survey Data
# 1      2008           AL        Alabama  Tobacco Use – Survey Data
# 2      2015           WV  West Virginia  Tobacco Use – Survey Data
# 3      2005           IL       Illinois  Tobacco Use – Survey Data
# 4      2005           CT    Connecticut  Tobacco Use – Survey Data
# ...     ...          ...            ...                        ...
# 10595  2002           KS         Kansas  Tobacco Use – Survey Data
# 10596  2015           IL       Illinois  Tobacco Use – Survey Data
# 10597  2010           WI      Wisconsin  Tobacco Use – Survey Data
# 10598  2009           LA      Louisiana  Tobacco Use – Survey Data
# 10599  2010           DE       Delaware  Tobacco Use – Survey Data
#
#                            TopicDesc  \
# 0              Cigarette Use (Youth)
# 1              Cigarette Use (Youth)
# 2      Smokeless Tobacco Use (Youth)
# ...

# %%
df1.loc[10599]  # here I have fetched
# Out:
# YEAR                                                   2010
# LocationAbbr                                             DE
# LocationDesc                                       Delaware
# TopicType                         Tobacco Use – Survey Data
# TopicDesc                             Cigarette Use (Youth)
# MeasureDesc                                  Smoking Status
# DataSource                                              YTS
# Response                                               Ever
# Data_Value_Unit                                           %
# Data_Value_Type                                  Percentage
# Data_Value                                             45.8
# Data_Value_Footnote_Symbol                              NaN
# Data_Value_Footnote                                     NaN
# Data_Value_Std_Err                                      2.2
# Low_Confidence_Limit                                   41.4
# High_Confidence_Limit                                  50.2
# ...

# %%
df3 = pd.read_csv(r"C:\Users\Admin\OneDrive\Desktop\Kaggle data new\World_Happiness_Report_2024.csv")

# %%
df3
# Out:
#               country  all_ages  the_young  lower_middle  upper_middle  \
# 0             Finland         1          7             1             1
# 1             Denmark         2          5             3             4
# 2             Iceland         3          4             4             2
# 3              Sweden         4         18             8             3
# 4              Israel         5          2             2             7
# ..                ...       ...        ...           ...           ...
# 138  Congo (Kinshasa)       139        140           137           134
# 139      Sierra Leone       140        141           136           132
# 140           Lesotho       141        138           141           142
# 141           Lebanon       142        142           142           141
# 142       Afghanistan       143        143           143           143
#
#      the_old happiest  least_happy
# 0          2      Old        Young
# 1          1      Old        Young
# ...

# %%
df3.loc[0:10]
# Out:
#         country  all_ages  the_young  lower_middle  upper_middle  the_old  \
# 0       Finland         1          7             1             1        2
# 1       Denmark         2          5             3             4        1
# 2       Iceland         3          4             4             2        5
# 3        Sweden         4         18             8             3        4
# 4        Israel         5          2             2             7       18
# 5   Netherlands         6          9             5             5        7
# 6        Norway         7         20             6             6        3
# 7    Luxembourg         8          6            11             8       12
# 8   Switzerland         9         13             9            11       14
# 9     Australia        10         19            14            10        9
# 10  New Zealand        11         27            18            13        6
#
#    happiest  least_happy
# 0       Old        Young
# 1       Old        Young
# ...

# %%
df3.loc[0:2,"country":"the_young"]
# Out:
#    country  all_ages  the_young
# 0  Finland         1          7
# 1  Denmark         2          5
# 2  Iceland         3          4

# %%
df3.iloc[0:3,0:5]
# Out:
#    country  all_ages  the_young  lower_middle  upper_middle
# 0  Finland         1          7             1             1
# 1  Denmark         2          5             3             4
# 2  Iceland         3          4             4             2

# %%
df3.loc[0:5]
# Out:
#        country  all_ages  the_young  lower_middle  upper_middle  the_old  \
# 0      Finland         1          7             1             1        2
# 1      Denmark         2          5             3             4        1
# 2      Iceland         3          4             4             2        5
# 3       Sweden         4         18             8             3        4
# 4       Israel         5          2             2             7       18
# 5  Netherlands         6          9             5             5        7
#
#   happiest  least_happy
# 0      Old        Young
# 1      Old        Young
# 2    Young  LowerMiddle
# 3      Old        Young
# 4    Young          Old
# 5      Old        Young

# %%
df3.iloc[0:5]
# Out:
#    country  all_ages  the_young  lower_middle  upper_middle  the_old happiest  \
# 0  Finland         1          7             1             1        2      Old
# 1  Denmark         2          5             3             4        1      Old
# 2  Iceland         3          4             4             2        5    Young
# 3   Sweden         4         18             8             3        4      Old
# 4   Israel         5          2             2             7       18    Young
#
#    least_happy
# 0        Young
# 1        Young
# 2  LowerMiddle
# 3        Young
# 4          Old

# %%
#  here we can see the differnce between loc and iloc

# if we fetch data by loc #df3.loc[0:5]# then it will 0-5 index all
# but 
# if we fetch data by loc #df3.iloc[0:5]# then it will 0-4 index all given index -1
