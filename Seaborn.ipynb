# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = [90,75,60,45,30,15,45.96,56]

# %%
bins = []
for i in range(0,101,10):
    bins.append(i)

# %%
sns.displot(df,bins=bins,kde=True)
# Out:
# C:\Users\Admin\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
df2 = pd.read_csv(r"F:\Kaggle data new\Iris.csv")

# %%
df2
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
# 1  Histogram

# %%
sns.distplot(df2["PetalLengthCm"],kde=False)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_8548\1145122986.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df2["PetalLengthCm"],kde=False)
# <Axes: xlabel='PetalLengthCm'>

# %%
# 2 Kernel density Estimates

# %%
sns.distplot(df2["PetalLengthCm"],hist=False)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_8548\3914503739.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df2["PetalLengthCm"],hist=False)
# C:\Users\Admin\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='PetalLengthCm', ylabel='Density'>

# %%
# 3 Fitting parametric distribution

# %%
sns.distplot(df2["PetalLengthCm"])
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_8548\1621885480.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df2["PetalLengthCm"])
# C:\Users\Admin\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
########## Plotting Bivariate Distribution   #######

# %%
#  1 Scatter plot

# %%
sns.jointplot(x="PetalLengthCm",y="PetalWidthCm",data=df2)
# Out:
# C:\Users\Admin\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Admin\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# 2 Hexbin plot

# %%
sns.jointplot(x="PetalLengthCm",y="PetalWidthCm",data=df2,kind="hex")
# Out:
# C:\Users\Admin\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Admin\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
########## Visualizing pairwise relationship    #######

# %%
sns.pairplot(df2,hue="Species",diag_kind="kde",kind="scatter",palette="husl")
plt.show()
# Out:
# C:\Users\Admin\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Admin\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Admin\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
###########  Plotting categorical data

# %%
df2
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
sns.stripplot(x="Species",y="PetalLengthCm",data=df2)
plt.show()
# Out:
# C:\Users\Admin\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Admin\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# 1 Stripplot

# %%
sns.stripplot(x="Species",y="PetalLengthCm",data=df2,jitter=True)
plt.show()
# Out:
# C:\Users\Admin\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Admin\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# 2 swarmplot

# %%
sns.swarmplot(x="Species",y="PetalLengthCm",data=df2)
# Out:
# C:\Users\Admin\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Admin\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Species', ylabel='PetalLengthCm'>
# C:\Users\Admin\anaconda3\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 10.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
# ########## Distribution of observation

# %%
# 1 Box plots

# %%
sns.boxplot(x="Species",y="PetalLengthCm",data=df2)
# Out:
# <Axes: xlabel='Species', ylabel='PetalLengthCm'>

# %%
# 2 Violin plots

# %%
df3 = pd.read_csv(r"F:\Kaggle data new\MyTransaction.csv")

# %%
df3
# Out:
#           Date   Category     RefNo    Date.1  Withdrawal  Deposit  Balance
# 0          NaN        NaN       NaN       NaN         NaN      NaN      NaN
# 1     1/1/2023       Rent  3.00E+11  1/1/2023      3950.0      0.0  1837.23
# 2     3/1/2023       Misc  3.00E+11  3/1/2023       105.0      0.0  1732.23
# 3     3/1/2023       Misc  3.37E+11  3/1/2023         0.0     55.0  1787.23
# 4     3/1/2023       Food  3.00E+11  3/1/2023        56.0      0.0  1731.23
# ...        ...        ...       ...       ...         ...      ...      ...
# 1465  13/12/23       Food  3.71E+11  13/12/23        26.0      0.0    46.68
# 1466  13/12/23       Food  3.71E+11  13/12/23        15.0      0.0    31.68
# 1467  13/12/23  Transport  3.35E+11  13/12/23         0.0   1718.0  1749.68
# 1468  13/12/23       Misc  3.71E+11  13/12/23      1718.0      0.0    31.68
# 1469  1/1/2024       Misc         0  31/12/23         0.0      8.0    39.68
#
# [1470 rows x 7 columns]

# %%
df6 =df3.head(10)

# %%
sns.violinplot(x="Withdrawal",y="Balance",data=df6)
# Out:
# <Axes: xlabel='Withdrawal', ylabel='Balance'>

# %%
sns.violinplot(x="Withdrawal",y="Balance",hue="Deposit",data=df6)
# Out:
# <Axes: xlabel='Withdrawal', ylabel='Balance'>

# %%
########## Statistical estimation

# %%
df4 = pd.read_csv(r"F:\Kaggle data new\World_Happiness_Report_2024.csv")

# %%
df5 =df4.head(10)

# %%
# 1 Bar plot

# %%
sns.barplot(x="Sex",y="Survived",hue="Pclass",data=df9)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[91], line 1
# ----> 1 sns.barplot(x="Sex",y="Survived",hue="Pclass",data=df9)
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:2763, in barplot(data, x, y, hue, order, hue_order, estimator, errorbar, n_boot, units, seed, orient, color, palette, saturation, width, errcolor, errwidth, capsize, dodge, ci, ax, **kwargs)
#    2760 if ax is None:
#    2761     ax = plt.gca()
# -> 2763 plotter.plot(ax, kwargs)
#    2764 return ax
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:1587, in _BarPlotter.plot(self, ax, bar_kws)
#    1585 """Make the plot."""
#    1586 self.draw_bars(ax, bar_kws)
# -> 1587 self.annotate_axes(ax)
#    1588 if self.orient == "h":
#    1589     ax.invert_yaxis()
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:767, in _CategoricalPlotter.annotate_axes(self, ax)
# ...

# %%
df8 = pd.read_csv(r'F:\Kaggle data new\huge_1M_titanic.csv')

# %%
df9 =df8.head(20)

# %%
df8
# Out:
#         PassengerId  Survived  Pclass                               Name  \
# 0              1310         1       1        Name1310, Miss. Surname1310
# 1              1311         0       3         Name1311, Col. Surname1311
# 2              1312         0       3          Name1312, Mr. Surname1312
# 3              1313         0       3          Name1313, Mr. Surname1313
# 4              1314         0       3          Name1314, Mr. Surname1314
# ...             ...       ...     ...                                ...
# 999995      1001305         0       2    Name1001305, Mr. Surname1001305
# 999996      1001306         1       1  Name1001306, Miss. Surname1001306
# 999997      1001307         0       3    Name1001307, Mr. Surname1001307
# 999998      1001308         0       2    Name1001308, Mr. Surname1001308
# 999999      1001309         1       1  Name1001309, Miss. Surname1001309
#
#            Sex   Age  SibSp  Parch            Ticket        Fare Cabin  \
# ...

# %%
df9
# Out:
#     PassengerId  Survived  Pclass                           Name     Sex  \
# 0          1310         1       1    Name1310, Miss. Surname1310  female
# 1          1311         0       3     Name1311, Col. Surname1311    male
# 2          1312         0       3      Name1312, Mr. Surname1312    male
# 3          1313         0       3      Name1313, Mr. Surname1313    male
# 4          1314         0       3      Name1314, Mr. Surname1314    male
# 5          1315         1       3  Name1315, Master. Surname1315  female
# 6          1316         0       1      Name1316, Mr. Surname1316    male
# 7          1317         1       2    Name1317, Miss. Surname1317  female
# 8          1318         0       1      Name1318, Mr. Surname1318    male
# 9          1319         0       2      Name1319, Mr. Surname1319    male
# 10         1320         1       3    Name1320, Miss. Surname1320  female
# 11         1321         0       3      Name1321, Mr. Surname1321    male
# ...

# %%
sns.countplot(x="Pclass",data=df9)
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
# 2 point plot

# %%
sns.pointplot(x="Sex",y="Survived",hue="Pclass",data=df9)
# Out:
# <Axes: xlabel='Sex', ylabel='Survived'>

# %%
##########  plotting wide form data

# %%
df2
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df11=df2.drop("Id",axis=1)

# %%
df11
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
sns.boxplot(data=df11,orient="h")
# Out:
# <Axes: >

# %%
########## multipanel categorical data

# %%
# 1  Factor plot

# %%
sns.factorplot(x="SepalLengthCm",y="SepalWidthCm",hue="kind",data=df11)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[105], line 1
# ----> 1 sns.factorplot(x="SepalLengthCm",y="SepalWidthCm",hue="kind",data=df11)
#
# AttributeError: module 'seaborn' has no attribute 'factorplot'

# %%
#  linear relationship

# %%
# 1 regplot
# 2 lmplot

# %%
sns.regplot(x="SepalLengthCm",y="SepalWidthCm",data=df11)
# Out:
# <Axes: xlabel='SepalLengthCm', ylabel='SepalWidthCm'>

# %%
sns.lmplot(x="SepalLengthCm",y="SepalWidthCm",data=df11)
